# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  #'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith',
                  ]

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "TCS"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from matplotlib import pyplot as plt

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_quality(ground_truth, predictions, metric_function, sort_values=False):
    quality_scores = {}
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    quality_scores = pd.Series(quality_scores.values(), index=quality_scores.keys())
    if sort_values:
        quality_scores = quality_scores.sort_values()
    
    return quality_scores

# %% [markdown]
# -------------

# %% [markdown]
# ## Prep data

# %%
# Read Data
df = pd.read_pickle(DF_PATH)

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1708
# Data or business analyst                          1658
# Data scientist or machine learning specialist     2460
# Database administrator                            1210
# DevOps specialist                                 3056
# Developer, QA or test                             1135
# Developer, back-end                              17084
# Developer, desktop or enterprise applications     4845
# Developer, embedded applications or devices       2138
# Developer, front-end                              8932
# Developer, full-stack                            20655
# Developer, game or graphics                        899
# Developer, mobile                                 4751
# Engineer, data                                    1941
# Scientist                                         1046
# System administrator                              2069
# dtype: int64

# %%
# Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        # Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=0)
    else:
        # Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=0)

    resampled_roles.append(sub_df)

# %%
# Construct dfs
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2280
# Data or business analyst                         1965
# Data scientist or machine learning specialist    2576
# Database administrator                           1765
# DevOps specialist                                2170
# Developer, QA or test                            1514
# Developer, back-end                              5710
# Developer, desktop or enterprise applications    2690
# Developer, embedded applications or devices      1773
# Developer, front-end                             2614
# Developer, full-stack                            5602
# Developer, game or graphics                      1441
# Developer, mobile                                2155
# Engineer, data                                   2046
# Scientist                                        1910
# System administrator                             2110
# dtype: int64

# %% [markdown]
# ## Split to train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# /var/folders/6x/qn2cr8jx24s9gcb3kx7w5g240000gn/T/ipykernel_39320/2536690730.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),

# %% [markdown]
# _________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. Vanilla Forest

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    4.4s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.4s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.3s finished

# %%
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# accuracy_score     92.635625
# precision_score    93.700625
# recall_score       49.920000
# f1_score           64.023125
# dtype: float64
#                                                accuracy_score  \
# Developer, full-stack                                   83.58
# Developer, back-end                                     79.60
# Developer, front-end                                    89.75
# Data scientist or machine learning specialist           93.90
# Developer, desktop or enterprise applications           90.73
# Academic researcher                                     94.98
# Scientist                                               97.06
# Developer, mobile                                       93.94
# Data or business analyst                                94.52
# Developer, embedded applications or devices             94.42
# DevOps specialist                                       92.81
# Developer, game or graphics                             98.06
# Database administrator                                  94.98
# Engineer, data                                          93.90
# System administrator                                    93.40
# Developer, QA or test                                   96.54
#
#                                                precision_score  recall_score  \
# Developer, full-stack                                    78.61         59.94
# Developer, back-end                                      84.46         39.00
# Developer, front-end                                     87.83         33.43
# Data scientist or machine learning specialist            90.07         61.57
# Developer, desktop or enterprise applications            92.67         33.44
# Academic researcher                                      93.15         61.15
# Scientist                                                94.70         75.76
# Developer, mobile                                        95.17         47.94
# Data or business analyst                                 95.56         48.47
# Developer, embedded applications or devices              95.68         37.26
# DevOps specialist                                        97.01         36.52
# Developer, game or graphics                              97.57         76.57
# Database administrator                                   98.55         46.15
# Engineer, data                                           99.06         42.03
# System administrator                                     99.55         41.26
# Developer, QA or test                                    99.57         58.23
#
#                                                f1_score
# Developer, full-stack                             68.02
# Developer, back-end                               53.36
# Developer, front-end                              48.43
# Data scientist or machine learning specialist     73.14
# Developer, desktop or enterprise applications     49.14
# Academic researcher                               73.83
# Scientist                                         84.18
# Developer, mobile                                 63.76
# Data or business analyst                          64.31
# Developer, embedded applications or devices       53.63
# DevOps specialist                                 53.06
# Developer, game or graphics                       85.80
# Database administrator                            62.87
# Engineer, data                                    59.02
# System administrator                              58.34
# Developer, QA or test                             73.48

# %% [markdown]
# ### Log

# %%
## Log
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %% [markdown]
# ______________

# %% [markdown]
# ### 2. Hyper parameter tuning

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# list(hpt_rf_clf.get_params().keys())
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   20.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   20.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   16.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   17.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.0s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 500}

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.5s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished

# %%
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     92.736250
# precision_score    89.576875
# recall_score       53.429375
# f1_score           65.972500
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     94.73
# Data or business analyst                                94.73
# Data scientist or machine learning specialist           94.21
# Database administrator                                  94.96
# DevOps specialist                                       92.83
# Developer, QA or test                                   96.54
# Developer, back-end                                     80.06
# Developer, desktop or enterprise applications           90.73
# Developer, embedded applications or devices             94.69
# Developer, front-end                                    89.81
# Developer, full-stack                                   84.21
# Developer, game or graphics                             97.77
# Developer, mobile                                       94.15
# Engineer, data                                          94.25
# Scientist                                               96.69
# System administrator                                    93.42
#
#                                                precision_score  recall_score  \
# Academic researcher                                      87.97         63.13
# Data or business analyst                                 90.97         53.58
# Data scientist or machine learning specialist            86.56         67.59
# Database administrator                                   96.73         46.83
# DevOps specialist                                        90.60         39.70
# Developer, QA or test                                    99.57         58.23
# Developer, back-end                                      77.62         46.87
# Developer, desktop or enterprise applications            86.94         36.24
# Developer, embedded applications or devices              90.86         43.03
# Developer, front-end                                     80.06         38.93
# Developer, full-stack                                    75.28         68.17
# Developer, game or graphics                              95.45         74.39
# Developer, mobile                                        91.48         52.25
# Engineer, data                                           96.69         46.61
# Scientist                                                89.81         76.57
# System administrator                                     96.64         42.75
#
#                                                f1_score
# Academic researcher                               73.51
# Data or business analyst                          67.44
# Data scientist or machine learning specialist     75.91
# Database administrator                            63.11
# DevOps specialist                                 55.21
# Developer, QA or test                             73.48
# Developer, back-end                               58.45
# Developer, desktop or enterprise applications     51.15
# Developer, embedded applications or devices       58.40
# Developer, front-end                              52.39
# Developer, full-stack                             71.55
# Developer, game or graphics                       83.61
# Developer, mobile                                 66.51
# Engineer, data                                    62.90
# Scientist                                         82.66
# System administrator                              59.28

# %% [markdown]
# ## Log

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
